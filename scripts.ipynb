# %%
import main
main.main()
# Out:
# classes:
#   class:
#   - full_name: Основы профессиональной деятельности(Лаб)
#     start: "08:20"
#     end: "09:50"
#     teacher: Пашнин Александр Денисович
#     location: "Кронверкский пр., д.49, лит.А"
#     room: 2306/2 (бывш. 305) ауд.
#     weeks:
#       week:
#       - 2
#       - 4
#       - 6
#       - 8
#       - 10
#       - 12
#       - 14
#       - 16
#     weeks_description: четная неделя
#     format: Очно - дистанционный
#     _name: ОПД(лаб)
#   - full_name: Основы профессиональной деятельности(Лаб)
#     start: "10:00"
#     end: "11:30"
#     teacher: Пашнин Александр Денисович
#     location: "Кронверкский пр., д.49, лит.А"
#     room: 2306/2 (бывш. 305) ауд.
#     weeks:
#       week:
#       - 2
#       - 4
#       - 6
#       - 8
#       - 10
#       - 12
#       - 14
#       - 16
#     weeks_description: четная неделя
#     format: Очно - дистанционный
#     _name: ОПД(лаб)
#   - full_name: Программирование(Лаб)
#     start: "08:20"
#     end: "09:50"
# ...

# %%
import main_with_regex
main_with_regex.main()
# Out:
# classes:
#   class:
#   - full_name: Основы профессиональной деятельности(Лаб)
#     start: "08:20"
#     end: "09:50"
#     teacher: Пашнин Александр Денисович
#     location: "Кронверкский пр., д.49, лит.А"
#     room: 2306/2 (бывш. 305) ауд.
#     weeks:
#       week:
#       - 2
#       - 4
#       - 6
#       - 8
#       - 10
#       - 12
#       - 14
#       - 16
#     weeks_description: четная неделя
#     format: Очно - дистанционный
#     _name: ОПД(лаб)
#   - full_name: Основы профессиональной деятельности(Лаб)
#     start: "10:00"
#     end: "11:30"
#     teacher: Пашнин Александр Денисович
#     location: "Кронверкский пр., д.49, лит.А"
#     room: 2306/2 (бывш. 305) ауд.
#     weeks:
#       week:
#       - 2
#       - 4
#       - 6
#       - 8
#       - 10
#       - 12
#       - 14
#       - 16
#     weeks_description: четная неделя
#     format: Очно - дистанционный
#     _name: ОПД(лаб)
#   - full_name: Программирование(Лаб)
#     start: "08:20"
#     end: "09:50"
# ...

# %%
import main_with_libs
main_with_libs.main()
# Out:
# classes:
#   '@week_day': monday
#   class:
#   - '@name': ОПД(лаб)
#     end: 09:50
#     format: Очно - дистанционный
#     full_name: Основы профессиональной деятельности(Лаб)
#     location: Кронверкский пр., д.49, лит.А
#     room: 2306/2 (бывш. 305) ауд.
#     start: 08:20
#     teacher: Пашнин Александр Денисович
#     weeks:
#       week:
#       - '2'
#       - '4'
#       - '6'
#       - '8'
#       - '10'
#       - '12'
#       - '14'
#       - '16'
#     weeks_description: четная неделя
#   - '@name': ОПД(лаб)
#     end: '11:30'
#     format: Очно - дистанционный
#     full_name: Основы профессиональной деятельности(Лаб)
#     location: Кронверкский пр., д.49, лит.А
#     room: 2306/2 (бывш. 305) ауд.
#     start: '10:00'
#     teacher: Пашнин Александр Денисович
#     weeks:
#       week:
#       - '2'
#       - '4'
#       - '6'
#       - '8'
#       - '10'
#       - '12'
#       - '14'
#       - '16'
#     weeks_description: четная неделя
#   - '@name': Прог(лаб)
# ...

# %%
import time_it
time_it.main()
# Out:
# Runs: 1000
# xml_parser: 0.7746438370086253 seconds
# xml_parser_with_regex: 0.7716838950000238 seconds
# xml_to_yaml_with_libs: 3.008504785990226 seconds
